# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
poa_jardim = pd.read_csv("POA_D10_JardimBotanico.csv")
poa_belem = pd.read_csv("POA_D10_BelemNovo.csv")

# %%
x = np.linspace(0, 23, num=24).tolist()

plt.plot(x, poa_jardim["Temp. Max. (C)"], label="Jardim Botanico")
plt.plot(x, poa_belem["Temp. Max. (C)"], label="Belem Novo")
plt.xlabel("Hora")
plt.ylabel("Temp. Max.")
plt.title("Pensando")
plt.legend()
plt.show()
